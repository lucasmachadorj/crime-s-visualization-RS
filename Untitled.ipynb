# %%
import pandas as pd
import sys  

reload(sys)  
sys.setdefaultencoding('utf8')

# %%
indicativos = pd.read_csv('indicativo.csv')

# %%
indicativos
# Out:
#         indice  municipio         fato  qtde   ano  mes         microrregiao  \
# 0            0     ACEGUA        furto     1  2002    4  Campanha Meridional
# 1            1     ACEGUA        furto     1  2002    7  Campanha Meridional
# 2            2     ACEGUA        furto     1  2002    9  Campanha Meridional
# 3            3     ACEGUA        furto     2  2002   12  Campanha Meridional
# 4            4     ACEGUA        furto     1  2003    1  Campanha Meridional
# 5            5     ACEGUA        furto     5  2003    1  Campanha Meridional
# 6            6     ACEGUA        roubo     1  2003    1  Campanha Meridional
# 7            7     ACEGUA        furto     4  2003    3  Campanha Meridional
# 8            8     ACEGUA        furto     4  2003    4  Campanha Meridional
# 9            9     ACEGUA        furto     5  2003    5  Campanha Meridional
# 10          10     ACEGUA        furto     4  2003    7  Campanha Meridional
# ...

# %%
regioes.rename(columns={u'Municípios': 'MUNICIPIO'}, inplace=True)

# %%
regioes.head()
# Out:
#                     MUNICIPIO       Microrregião  \
# 0                       Agudo      Restinga Seca
# 1              Dona Francisca      Restinga Seca
# 2          Faxinal do Soturno      Restinga Seca
# 3                 Formigueiro      Restinga Seca
# 4                       Ivorá      Restinga Seca
#
#                       Mesorregião
# 0  Centro Ocidental Rio-Grandense
# 1  Centro Ocidental Rio-Grandense
# 2  Centro Ocidental Rio-Grandense
# 3  Centro Ocidental Rio-Grandense
# 4  Centro Ocidental Rio-Grandense

# %%
regioes[u'MUNICIPIO'] = map(lambda x: x.upper(), regioes[u'MUNICIPIO'])

# %%
regioes[u'MUNICIPIO'] = map(lambda x: x.replace('Ç','C'), regioes[u'MUNICIPIO'])
regioes[u'MUNICIPIO'] = map(lambda x: x.replace('Á','A'), regioes[u'MUNICIPIO'])
regioes[u'MUNICIPIO'] = map(lambda x: x.replace('Ã','A'), regioes[u'MUNICIPIO'])
regioes[u'MUNICIPIO'] = map(lambda x: x.replace('Ê','E'), regioes[u'MUNICIPIO'])
regioes[u'MUNICIPIO'] = map(lambda x: x.replace('Í','I'), regioes[u'MUNICIPIO'])
regioes[u'MUNICIPIO'] = map(lambda x: x.replace('Ó','O'), regioes[u'MUNICIPIO'])
regioes[u'MUNICIPIO'] = map(lambda x: x.replace('Õ','O'), regioes[u'MUNICIPIO'])
regioes[u'MUNICIPIO'] = map(lambda x: x.replace('Ú','U'), regioes[u'MUNICIPIO'])
regioes[u'MUNICIPIO'] = map(lambda x: x.replace('É','E'), regioes[u'MUNICIPIO'])
regioes[u'MUNICIPIO'] = map(lambda x: x.replace('Â','A'), regioes[u'MUNICIPIO'])
regioes[u'MUNICIPIO'] = map(lambda x: x.replace('Ô','O'), regioes[u'MUNICIPIO'])

# %%
l = set(regioes.MUNICIPIO.str.strip().tolist())

# %%
len(l)
# Out:
# 497

# %%
l
# Out:
# {u'ACEGUA',
#  u'AGUA SANTA',
#  u'AGUDO',
#  u'AJURICABA',
#  u'ALECRIM',
#  u'ALEGRETE',
#  u'ALEGRIA',
#  u'ALMIRANTE TAMANDARE DO SUL',
#  u'ALPESTRE',
#  u'ALTO ALEGRE',
#  u'ALTO FELIZ',
#  u'ALVORADA',
#  u'AMARAL FERRADOR',
#  u'AMETISTA DO SUL',
#  u'ANDRE DA ROCHA',
#  u'ANTA GORDA',
#  u'ANTONIO PRADO',
#  u'ARAMBARE',
#  u'ARARICA',
#  u'ARATIBA',
#  u'ARROIO DO MEIO',
#  u'ARROIO DO PADRE',
#  u'ARROIO DO SAL',
#  u'ARROIO DO TIGRE',
#  u'ARROIO DOS RATOS',
#  u'ARROIO GRANDE',
#  u'ARVOREZINHA',
#  u'AUGUSTO PESTANA',
#  u'AUREA',
#  u'BAGE',
#  u'BALNEARIO PINHAL',
#  u'BARAO',
#  u'BARAO DE COTEGIPE',
#  u'BARAO DO TRIUNFO',
#  u'BARRA DO GUARITA',
#  u'BARRA DO QUARAI',
#  u'BARRA DO RIBEIRO',
#  u'BARRA DO RIO AZUL',
#  u'BARRA FUNDA',
#  u'BARRACAO',
#  u'BARROS CASSAL',
#  u'BENJAMIN CONSTANT DO SUL',
#  u'BENTO GONCALVES',
#  u'BOA VISTA DAS MISSOES',
#  u'BOA VISTA DO BURICA',
#  u'BOA VISTA DO CADEADO',
#  u'BOA VISTA DO INCRA',
#  u'BOA VISTA DO SUL',
# ...

# %%
p = set(indicativos.MUNICIPIO.tolist())

# %%
len(p)
# Out:
# 497

# %%
p
# Out:
# {'ACEGUA',
#  'AGUA SANTA',
#  'AGUDO',
#  'AJURICABA',
#  'ALECRIM',
#  'ALEGRETE',
#  'ALEGRIA',
#  'ALMIRANTE TAMANDARE DO SUL',
#  'ALPESTRE',
#  'ALTO ALEGRE',
#  'ALTO FELIZ',
#  'ALVORADA',
#  'AMARAL FERRADOR',
#  'AMETISTA DO SUL',
#  'ANDRE DA ROCHA',
#  'ANTA GORDA',
#  'ANTONIO PRADO',
#  'ARAMBARE',
#  'ARARICA',
#  'ARATIBA',
#  'ARROIO DO MEIO',
#  'ARROIO DO PADRE',
#  'ARROIO DO SAL',
#  'ARROIO DO TIGRE',
#  'ARROIO DOS RATOS',
#  'ARROIO GRANDE',
#  'ARVOREZINHA',
#  'AUGUSTO PESTANA',
#  'AUREA',
#  'BAGE',
#  'BALNEARIO PINHAL',
#  'BARAO',
#  'BARAO DE COTEGIPE',
#  'BARAO DO TRIUNFO',
#  'BARRA DO GUARITA',
#  'BARRA DO QUARAI',
#  'BARRA DO RIBEIRO',
#  'BARRA DO RIO AZUL',
#  'BARRA FUNDA',
#  'BARRACAO',
#  'BARROS CASSAL',
#  'BENJAMIN CONSTANT DO SUL',
#  'BENTO GONCALVES',
#  'BOA VISTA DAS MISSOES',
#  'BOA VISTA DO BURICA',
#  'BOA VISTA DO CADEADO',
#  'BOA VISTA DO INCRA',
#  'BOA VISTA DO SUL',
#  'BOM JESUS',
#  'BOM PRINCIPIO',
#  'BOM PROGRESSO',
# ...

# %%
l-p
# Out:
# {u'DOUTOR MAURICIO CARDOSO',
#  u'ENTRE-IJUIS',
#  u'FAZENDA VILANOVA',
#  u'PINTO BANDEIRA'}

# %%
p-l
# Out:
# {'DR MAURICIO CARDOSO',
#  'ENTRE IJUIS',
#  'FAZENDA VILA NOVA',
#  'PINTO BANDEIRA (BENTO GONC)'}

# %%
regioes[u'MUNICIPIO'] = map(lambda x: x.strip(), regioes[u'MUNICIPIO'])

# %%
regioes
# Out:
#                   MUNICIPIO             Microrregião  \
# 0                     AGUDO            Restinga Seca
# 1            DONA FRANCISCA            Restinga Seca
# 2        FAXINAL DO SOTURNO            Restinga Seca
# 3               FORMIGUEIRO            Restinga Seca
# 4                     IVORA            Restinga Seca
# 5                NOVA PALMA            Restinga Seca
# 6             RESTINGA SECA            Restinga Seca
# 7      SAO JOAO DO POLESINE            Restinga Seca
# 8          SILVEIRA MARTINS            Restinga Seca
# 9                   CACEQUI              Santa Maria
# 10     DILERMANDO DE AGUIAR              Santa Maria
# 11                   ITAARA              Santa Maria
# 12                  JAGUARI              Santa Maria
# 13                     MATA              Santa Maria
# 14    NOVA ESPERANCA DO SUL              Santa Maria
# 15              SANTA MARIA              Santa Maria
# 16    SAO MARTINHO DA SERRA              Santa Maria
# ...

# %%
len(l), len(p)
# Out:
# (497, 497)

# %%
regioes[u'MUNICIPIO'][u'DOUTOR MAURICIO CARDOSO'] = u'DR MAURICIO CARDOSO'
regioes[u'MUNICIPIO'][u'ENTRE-IJUIS'] = u'ENTRE IJUIS'
regioes[u'MUNICIPIO'][u'FAZENDA VILANOVA'] = u'FAZENDA VILA NOVA'
regioes[u'MUNICIPIO'][u'PINTO BANDEIRA'] = u'PINTO BANDEIRA (BENTO GONC)'

# %%
l = set(regioes.MUNICIPIO.str.strip().tolist())

# %%
l-p
# Out:
# {u'DOUTOR MAURICIO CARDOSO',
#  u'ENTRE-IJUIS',
#  u'FAZENDA VILANOVA',
#  u'PINTO BANDEIRA'}

# %%
len(p)
# Out:
# 497

# %%
regioes[u'MUNICIPIO'].replace(to_replace=u'DOUTOR MAURICIO CARDOSO', value='DR MAURICIO CARDOSO', regex=True, inplace=True)

# %%
regioes[u'MUNICIPIO'].replace(to_replace=u'ENTRE-IJUIS', value='ENTRE IJUIS', regex=True, inplace=True)
regioes[u'MUNICIPIO'].replace(to_replace=u'FAZENDA VILANOVA', value='FAZENDA VILA NOVA', regex=True, inplace=True)
regioes[u'MUNICIPIO'].replace(to_replace=u'PINTO BANDEIRA', value='PINTO BANDEIRA (BENTO GONC)', regex=True, inplace=True)

# %%
l = set(regioes.MUNICIPIO.str.strip().tolist())

# %%
l-p
# Out:
# set()

# %%
p-l
# Out:
# set()

# %%
len(p), len(l)
# Out:
# (497, 497)

# %%
regioes.head()
# Out:
#             MUNICIPIO       Microrregião                     Mesorregião
# 0               AGUDO      Restinga Seca  Centro Ocidental Rio-Grandense
# 1      DONA FRANCISCA      Restinga Seca  Centro Ocidental Rio-Grandense
# 2  FAXINAL DO SOTURNO      Restinga Seca  Centro Ocidental Rio-Grandense
# 3         FORMIGUEIRO      Restinga Seca  Centro Ocidental Rio-Grandense
# 4               IVORA      Restinga Seca  Centro Ocidental Rio-Grandense

# %%
indicativos.head()
# Out:
#    INDICE   MUNICIPIO   FATO  QTDE   ANO  MES
# 0       0      ACEGUA  furto     1  2002    4
# 1       1      ACEGUA  furto     1  2002    7
# 2       2      ACEGUA  furto     1  2002    9
# 3       3      ACEGUA  furto     2  2002   12
# 4       4  AGUA SANTA  furto     1  2002    1

# %%
merge_inner = pd.merge(left=indicativos, right=regioes, left_on='MUNICIPIO', right_on='MUNICIPIO')

# %%
merge_inner
# Out:
#         INDICE  MUNICIPIO         FATO  QTDE   ANO  MES  \
# 0            0     ACEGUA        furto     1  2002    4
# 1            1     ACEGUA        furto     1  2002    7
# 2            2     ACEGUA        furto     1  2002    9
# 3            3     ACEGUA        furto     2  2002   12
# 4            0     ACEGUA        furto     1  2003    1
# 5            1     ACEGUA        furto     5  2003    1
# 6            2     ACEGUA        roubo     1  2003    1
# 7            3     ACEGUA        furto     4  2003    3
# 8            4     ACEGUA        furto     4  2003    4
# 9            5     ACEGUA        furto     5  2003    5
# 10           6     ACEGUA        furto     4  2003    7
# 11           7     ACEGUA        furto     3  2003    8
# 12           8     ACEGUA        furto     6  2003    9
# 13           9     ACEGUA        furto     4  2003   10
# 14          10     ACEGUA        furto     2  2003   11
# 15          11     ACEGUA        roubo     1  2003   11
# ...

# %%
merge_inner = merge_inner.drop('INDICE', 1)

# %%
merge_inner.head()
# Out:
#   MUNICIPIO   FATO  QTDE   ANO  MES             Microrregião  \
# 0    ACEGUA  furto     1  2002    4      Campanha Meridional
# 1    ACEGUA  furto     1  2002    7      Campanha Meridional
# 2    ACEGUA  furto     1  2002    9      Campanha Meridional
# 3    ACEGUA  furto     2  2002   12      Campanha Meridional
# 4    ACEGUA  furto     1  2003    1      Campanha Meridional
#
#               Mesorregião
# 0  Sudoeste Rio-Grandense
# 1  Sudoeste Rio-Grandense
# 2  Sudoeste Rio-Grandense
# 3  Sudoeste Rio-Grandense
# 4  Sudoeste Rio-Grandense

# %%
merge_inner.to_csv('indicativos.csv')

# %%
indicativos = pd.read_csv(source + 'indicativo.csv')

# %%
indicativos = indicativos.drop('a',1)

# %%
indicativos.head()
# Out:
#   MUNICIPIO   FATO  QTDE   ANO  MES             Microrregião  \
# 0    ACEGUA  furto     1  2002    4      Campanha Meridional
# 1    ACEGUA  furto     1  2002    7      Campanha Meridional
# 2    ACEGUA  furto     1  2002    9      Campanha Meridional
# 3    ACEGUA  furto     2  2002   12      Campanha Meridional
# 4    ACEGUA  furto     1  2003    1      Campanha Meridional
#
#               Mesorregião
# 0  Sudoeste Rio-Grandense
# 1  Sudoeste Rio-Grandense
# 2  Sudoeste Rio-Grandense
# 3  Sudoeste Rio-Grandense
# 4  Sudoeste Rio-Grandense

# %%
indicativos['Microrregião'] = map(lambda x: x.strip(), indicativos['Microrregião'])

# %%
indicativos['Mesorregião'] = map(lambda x: x.strip(), indicativos['Mesorregião'])

# %%
indicativos.rename(columns={'Microrregião': u'MICRORREGIAO'}, inplace=True)
indicativos.rename(columns={'Mesorregião': u'MESORREGIAO'}, inplace=True)

# %%
indicativos.head()
# Out:
#   MUNICIPIO   FATO  QTDE   ANO  MES         MICRORREGIAO  \
# 0    ACEGUA  furto     1  2002    4  Campanha Meridional
# 1    ACEGUA  furto     1  2002    7  Campanha Meridional
# 2    ACEGUA  furto     1  2002    9  Campanha Meridional
# 3    ACEGUA  furto     2  2002   12  Campanha Meridional
# 4    ACEGUA  furto     1  2003    1  Campanha Meridional
#
#               MESORREGIAO
# 0  Sudoeste Rio-Grandense
# 1  Sudoeste Rio-Grandense
# 2  Sudoeste Rio-Grandense
# 3  Sudoeste Rio-Grandense
# 4  Sudoeste Rio-Grandense

# %%
indicativos.to_csv('static/indicativos.csv')

# %%
indicativos.head()
# Out:
#    indice municipio   fato  qtde   ano  mes         microrregiao  \
# 0       0    ACEGUA  furto     1  2002    4  Campanha Meridional
# 1       1    ACEGUA  furto     1  2002    7  Campanha Meridional
# 2       2    ACEGUA  furto     1  2002    9  Campanha Meridional
# 3       3    ACEGUA  furto     2  2002   12  Campanha Meridional
# 4       4    ACEGUA  furto     1  2003    1  Campanha Meridional
#
#               mesorregiao
# 0  Sudoeste Rio-Grandense
# 1  Sudoeste Rio-Grandense
# 2  Sudoeste Rio-Grandense
# 3  Sudoeste Rio-Grandense
# 4  Sudoeste Rio-Grandense

# %%
del indicativos['indice']

# %%
indicativos.head()
# Out:
#   municipio   fato  qtde   ano  mes         microrregiao  \
# 0    ACEGUA  furto     1  2002    4  Campanha Meridional
# 1    ACEGUA  furto     1  2002    7  Campanha Meridional
# 2    ACEGUA  furto     1  2002    9  Campanha Meridional
# 3    ACEGUA  furto     2  2002   12  Campanha Meridional
# 4    ACEGUA  furto     1  2003    1  Campanha Meridional
#
#               mesorregiao
# 0  Sudoeste Rio-Grandense
# 1  Sudoeste Rio-Grandense
# 2  Sudoeste Rio-Grandense
# 3  Sudoeste Rio-Grandense
# 4  Sudoeste Rio-Grandense

# %%
meses = {1:'janeiro',2:'fevereiro',3:'março',4:'abril',5:'maio',6:'junho',7:'julho',8:'agosto',9:'setembro',10:'outubro',11:'novembro',12:'dezembro'}

# %%
path = indicativos.replace({"mes":meses})

# %%
indicativos['path'] = indicativos.apply(lambda x: str(x.ano) + '-' + str(x.mesorregiao) + '-' + str(x.fato) + '-' + str(x.qtde), axis=1)

# %%
indicativos
# Out:
#         municipio         fato  qtde   ano  mes         microrregiao  \
# 0          ACEGUA        furto     1  2002    4  Campanha Meridional
# 1          ACEGUA        furto     1  2002    7  Campanha Meridional
# 2          ACEGUA        furto     1  2002    9  Campanha Meridional
# 3          ACEGUA        furto     2  2002   12  Campanha Meridional
# 4          ACEGUA        furto     1  2003    1  Campanha Meridional
# 5          ACEGUA        furto     5  2003    1  Campanha Meridional
# 6          ACEGUA        roubo     1  2003    1  Campanha Meridional
# 7          ACEGUA        furto     4  2003    3  Campanha Meridional
# 8          ACEGUA        furto     4  2003    4  Campanha Meridional
# 9          ACEGUA        furto     5  2003    5  Campanha Meridional
# 10         ACEGUA        furto     4  2003    7  Campanha Meridional
# 11         ACEGUA        furto     3  2003    8  Campanha Meridional
# 12         ACEGUA        furto     6  2003    9  Campanha Meridional
# ...

# %%
del path['path']

# %%
path['path'] = path.apply(lambda x: str(x.ano) + '-' + str(x.mesorregiao) + '-' + str(x.fato), axis=1)

# %%
del path['path']

# %%
k['path'] = path['path']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-42a201f07cde> in <module>()
# ----> 1 k['path'] = path['path']
#
# NameError: name 'k' is not defined

# %%
t['qtde'] = path['qtde']

# %%
df = path['path':'qtde']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-9b84332f2af7> in <module>()
# ----> 1 df = path['path':'qtde']
#
# /home/machado/anaconda/envs/data_mining/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1779         indexer = convert_to_index_sliceable(self, key)
#    1780         if indexer is not None:
# -> 1781             return self._getitem_slice(indexer)
#    1782
#    1783         if isinstance(key, (Series, np.ndarray, Index, list)):
#
# /home/machado/anaconda/envs/data_mining/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_slice(self, key)
#    1806
#    1807     def _getitem_slice(self, key):
# -> 1808         return self._slice(key, axis=0)
#    1809
#    1810     def _getitem_array(self, key):
#
# ...

# %%
k = path['path']

# %%
k['qtde'] = path['qtde']

# %%
k = path[['path','qtde']]

# %%
k
# Out:
#                                             path  qtde
# 0              2002-Sudoeste Rio Grandense-furto     1
# 1              2002-Sudoeste Rio Grandense-furto     1
# 2              2002-Sudoeste Rio Grandense-furto     1
# 3              2002-Sudoeste Rio Grandense-furto     2
# 4              2003-Sudoeste Rio Grandense-furto     1
# 5              2003-Sudoeste Rio Grandense-furto     5
# 6              2003-Sudoeste Rio Grandense-roubo     1
# 7              2003-Sudoeste Rio Grandense-furto     4
# 8              2003-Sudoeste Rio Grandense-furto     4
# 9              2003-Sudoeste Rio Grandense-furto     5
# 10             2003-Sudoeste Rio Grandense-furto     4
# 11             2003-Sudoeste Rio Grandense-furto     3
# 12             2003-Sudoeste Rio Grandense-furto     6
# 13             2003-Sudoeste Rio Grandense-furto     4
# 14             2003-Sudoeste Rio Grandense-furto     2
# 15             2003-Sudoeste Rio Grandense-roubo     1
# ...

# %%
k.to_csv('path.csv',header=False, index=False)

# %%
p = path['path']

# %%
t = path['path']

# %%
path['mesorregiao'] = path['mesorregiao'].str.replace("-"," ")

# %%
path.mesorregiao
# Out:
# 0                Sudoeste Rio Grandense
# 1                Sudoeste Rio Grandense
# 2                Sudoeste Rio Grandense
# 3                Sudoeste Rio Grandense
# 4                Sudoeste Rio Grandense
# 5                Sudoeste Rio Grandense
# 6                Sudoeste Rio Grandense
# 7                Sudoeste Rio Grandense
# 8                Sudoeste Rio Grandense
# 9                Sudoeste Rio Grandense
# 10               Sudoeste Rio Grandense
# 11               Sudoeste Rio Grandense
# 12               Sudoeste Rio Grandense
# 13               Sudoeste Rio Grandense
# 14               Sudoeste Rio Grandense
# 15               Sudoeste Rio Grandense
# 16               Sudoeste Rio Grandense
# 17               Sudoeste Rio Grandense
# 18               Sudoeste Rio Grandense
# 19               Sudoeste Rio Grandense
# 20               Sudoeste Rio Grandense
# 21               Sudoeste Rio Grandense
# 22               Sudoeste Rio Grandense
# ...

# %%
t =
