# %%
import pandas as pd

# %%
frame = pd.read_csv("indicativo.csv")

# %%
frame.head()
# Out:
#    indice municipio   fato  qtde   ano  mes         microrregiao  \
# 0       0    ACEGUA  furto     1  2002    4  Campanha Meridional
# 1       1    ACEGUA  furto     1  2002    7  Campanha Meridional
# 2       2    ACEGUA  furto     1  2002    9  Campanha Meridional
# 3       3    ACEGUA  furto     2  2002   12  Campanha Meridional
# 4       4    ACEGUA  furto     1  2003    1  Campanha Meridional
#
#               mesorregiao
# 0  Sudoeste Rio-Grandense
# 1  Sudoeste Rio-Grandense
# 2  Sudoeste Rio-Grandense
# 3  Sudoeste Rio-Grandense
# 4  Sudoeste Rio-Grandense

# %%
frame['mesorregiao'] = frame['mesorregiao'].apply(lambda x: x.replace("-"," "))
# frame['mesorregiao'] = frame['mesorregiao'].apply(lambda x: x.replace(" ","."))

# %%
frame['microrregiao'] = frame['microrregiao'].apply(lambda x: x.replace("-"," "))
# frame['microrregiao'] = frame['microrregiao'].apply(lambda x: x.replace(" ","."))

# %%
frame['fato'] = frame['fato'].apply(lambda x: x.replace("-"," "))
# frame['fato'] = frame['fato'].apply(lambda x: x.replace(" ","."))

# %%
frame['caminho'] = frame['mes'] + "-" + frame['mesorregiao'] + "-" + frame['microrregiao'] + "-" + frame['fato']

# %%
frame['caminho']
# Out:
# 0         abril-Sudoeste.Rio.Grandense-Campanha.Meridion...
# 1         julho-Sudoeste.Rio.Grandense-Campanha.Meridion...
# 2         setembro-Sudoeste.Rio.Grandense-Campanha.Merid...
# 3         dezembro-Sudoeste.Rio.Grandense-Campanha.Merid...
# 4         janeiro-Sudoeste.Rio.Grandense-Campanha.Meridi...
# 5         janeiro-Sudoeste.Rio.Grandense-Campanha.Meridi...
# 6         janeiro-Sudoeste.Rio.Grandense-Campanha.Meridi...
# 7         marco-Sudoeste.Rio.Grandense-Campanha.Meridion...
# 8         abril-Sudoeste.Rio.Grandense-Campanha.Meridion...
# 9         maio-Sudoeste.Rio.Grandense-Campanha.Meridiona...
# 10        julho-Sudoeste.Rio.Grandense-Campanha.Meridion...
# 11        agosto-Sudoeste.Rio.Grandense-Campanha.Meridio...
# 12        setembro-Sudoeste.Rio.Grandense-Campanha.Merid...
# 13        outubro-Sudoeste.Rio.Grandense-Campanha.Meridi...
# 14        novembro-Sudoeste.Rio.Grandense-Campanha.Merid...
# 15        novembro-Sudoeste.Rio.Grandense-Campanha.Merid...
# ...

# %%
month = {1:"janeiro",2:"fevereiro",3:"marco",4:"abril",5:"maio",6:"junho",7:"julho",8:"agosto",
         9:"setembro",10:"outubro",11:"novembro",12:"dezembro"}

frame['mes'].replace(month, inplace=True)

# %%
frame
# Out:
#         indice  municipio         fato  qtde   ano      mes  \
# 0            0     ACEGUA        furto     1  2002  janeiro
# 1            1     ACEGUA        furto     1  2002  janeiro
# 2            2     ACEGUA        furto     1  2002  janeiro
# 3            3     ACEGUA        furto     2  2002  janeiro
# 4            4     ACEGUA        furto     1  2003  janeiro
# 5            5     ACEGUA        furto     5  2003  janeiro
# 6            6     ACEGUA        roubo     1  2003  janeiro
# 7            7     ACEGUA        furto     4  2003  janeiro
# 8            8     ACEGUA        furto     4  2003  janeiro
# 9            9     ACEGUA        furto     5  2003  janeiro
# 10          10     ACEGUA        furto     4  2003  janeiro
# 11          11     ACEGUA        furto     3  2003  janeiro
# 12          12     ACEGUA        furto     6  2003  janeiro
# 13          13     ACEGUA        furto     4  2003  janeiro
# 14          14     ACEGUA        furto     2  2003  janeiro
# ...

# %%
frame.head()
# Out:
#    indice municipio   fato  qtde   ano       mes         microrregiao  \
# 0       0    ACEGUA  furto     1  2002     abril  Campanha.Meridional
# 1       1    ACEGUA  furto     1  2002     julho  Campanha.Meridional
# 2       2    ACEGUA  furto     1  2002  setembro  Campanha.Meridional
# 3       3    ACEGUA  furto     2  2002  dezembro  Campanha.Meridional
# 4       4    ACEGUA  furto     1  2003   janeiro  Campanha.Meridional
#
#               mesorregiao                                            caminho
# 0  Sudoeste.Rio.Grandense  abril-Sudoeste.Rio.Grandense-Campanha.Meridion...
# 1  Sudoeste.Rio.Grandense  julho-Sudoeste.Rio.Grandense-Campanha.Meridion...
# 2  Sudoeste.Rio.Grandense  setembro-Sudoeste.Rio.Grandense-Campanha.Merid...
# 3  Sudoeste.Rio.Grandense  dezembro-Sudoeste.Rio.Grandense-Campanha.Merid...
# 4  Sudoeste.Rio.Grandense  janeiro-Sudoeste.Rio.Grandense-Campanha.Meridi...

# %%
frame2002 = frame[frame.ano == 2002]
frame2003 = frame[frame.ano == 2003]
frame2004 = frame[frame.ano == 2004]
frame2005 = frame[frame.ano == 2005]
frame2006 = frame[frame.ano == 2006]
frame2007 = frame[frame.ano == 2007]
frame2008 = frame[frame.ano == 2008]
frame2009 = frame[frame.ano == 2009]
frame2010 = frame[frame.ano == 2010]
frame2011 = frame[frame.ano == 2011]

# %%
frame2002 = frame2002.drop(["indice","municipio","fato","mes","microrregiao","mesorregiao","ano"],1)
frame2003 = frame2003.drop(["indice","municipio","fato","mes","microrregiao","mesorregiao","ano"],1)
frame2004 = frame2004.drop(["indice","municipio","fato","mes","microrregiao","mesorregiao","ano"],1)
frame2005 = frame2005.drop(["indice","municipio","fato","mes","microrregiao","mesorregiao","ano"],1)
frame2006 = frame2006.drop(["indice","municipio","fato","mes","microrregiao","mesorregiao","ano"],1)
frame2007 = frame2007.drop(["indice","municipio","fato","mes","microrregiao","mesorregiao","ano"],1)
frame2008 = frame2008.drop(["indice","municipio","fato","mes","microrregiao","mesorregiao","ano"],1)
frame2009 = frame2009.drop(["indice","municipio","fato","mes","microrregiao","mesorregiao","ano"],1)
frame2010 = frame2010.drop(["indice","municipio","fato","mes","microrregiao","mesorregiao","ano"],1)
frame2011 = frame2011.drop(["indice","municipio","fato","mes","microrregiao","mesorregiao","ano"],1)

# %%
frame2005.head()
# Out:
#     qtde                                            caminho
# 31     5  janeiro-Sudoeste Rio Grandense-Campanha Meridi...
# 32     7  fevereiro-Sudoeste Rio Grandense-Campanha Meri...
# 33    13  marco-Sudoeste Rio Grandense-Campanha Meridion...
# 34     6  abril-Sudoeste Rio Grandense-Campanha Meridion...
# 35     4  maio-Sudoeste Rio Grandense-Campanha Meridiona...

# %%
cols = frame2002.columns.tolist()
col = []
col.append(cols[1])
col.append(cols[0])
col
# Out:
# ['caminho', 'qtde']

# %%
frame2002 = frame2002[col]
frame2003 = frame2003[col]
frame2004 = frame2004[col]
frame2005 = frame2005[col]
frame2006 = frame2006[col]
frame2007 = frame2007[col]
frame2008 = frame2008[col]
frame2009 = frame2009[col]
frame2010 = frame2010[col]
frame2011 = frame2011[col]

# %%
frame2007.head()
# Out:
#                                               caminho  qtde
# 67  janeiro-Sudoeste Rio Grandense-Campanha Meridi...     9
# 68  fevereiro-Sudoeste Rio Grandense-Campanha Meri...     9
# 69  marco-Sudoeste Rio Grandense-Campanha Meridion...     4
# 70  abril-Sudoeste Rio Grandense-Campanha Meridion...     6
# 71  maio-Sudoeste Rio Grandense-Campanha Meridiona...     5

# %%
frame2002.to_csv("path2002.csv",sep=",", index=False)
frame2003.to_csv("path2003.csv",sep=",", index=False)
frame2004.to_csv("path2004.csv",sep=",", index=False)
frame2005.to_csv("path2005.csv",sep=",", index=False)
frame2006.to_csv("path2006.csv",sep=",", index=False)
frame2007.to_csv("path2007.csv",sep=",", index=False)
frame2008.to_csv("path2008.csv",sep=",", index=False)
frame2009.to_csv("path2009.csv",sep=",", index=False)
frame2010.to_csv("path2010.csv",sep=",", index=False)
frame2011.to_csv("path2011.csv",sep=",", index=False)

# %%
frameA = pd.read_csv("indicativo.csv")

# %%
frameA.ano.unique()
# Out:
# array([2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012])
